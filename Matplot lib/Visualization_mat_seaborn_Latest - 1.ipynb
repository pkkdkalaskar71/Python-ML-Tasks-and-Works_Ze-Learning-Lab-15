# %%
# pandas = manuplation
# matplotlib = vizualization
# seaborn = visualization
# numpy = multidimension calculation

# %% [markdown]
# line
#
# subplot
#
# bar
#
# histogram
#
# pie
#
# box
#
# scatter

# %%
# pip install matplotlib

# %%
#install and then import matplotlib
# import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
ab = [-3, 5, 7,9]
gh = [10, 2, 5,12]
plt.plot(ab, gh)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3]
y = np.array([[1, 2], [3, 4], [5, 6]])
fig = plt.figure(figsize=(20,3))
plt.plot(x, y);

# %%
x = [-3, 5, 7,9]
y = [10, 2, 5,12]
fig = plt.figure(figsize=(20,5))
plt.plot(x, y,'go--', linewidth=5, markersize=19)
plt.xlabel('x data')
plt.ylabel('Y data')
plt.xlim(-5,10)
plt.ylim(-5, 15)
plt.title('Line Plot')
plt.suptitle('Sales Trend 2016-24', size=25, y=1.04)
# Out:
# Text(0.5, 1.04, 'Sales Trend 2016-24')

# %%
fig.savefig('example1.png', dpi=50, )

# %% [markdown]
# #### Matplotlib

# %%
import pandas as pd

# %%
pd.read_csv('D:\Feb Jul Aug\pandas\Salaries.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# C:\Users\USER\AppData\Local\Temp\ipykernel_8880\826861830.py:1: SyntaxWarning: invalid escape sequence '\F'
#   pd.read_csv('D:\Feb Jul Aug\pandas\Salaries.csv')
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
pd.read_csv('D:\\15 June10 12\\pandas\\Salaries.csv')
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df = pd.read_csv(r'D:\15 June10 12\pandas\Salaries.csv')
df
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
plt.hist(df['salary'])  #,orientation='horizontal');
plt.show()

# %%
df['rank'].value_counts()
# Out:
# rank
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: count, dtype: int64

# %%
plt.pie(df['rank'].value_counts(),autopct='%0.2f %%',labels=['Prof','AsstProf','AssocProf'],);

# %%
# df['rank'].value_counts().plot(kind='bar')

# %%
mtcars = pd.read_csv("mtcars.csv")

# %%
mtcars.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
plt.boxplot(mtcars['mpg']);

# %%
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
mtcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     int64
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     int64
#  8   am      32 non-null     int64
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(6)
# memory usage: 2.9 KB

# %%
mtcars['hp']
# Out:
# 0     110
# 1     110
# 2      93
# 3     110
# 4     175
# 5     105
# 6     245
# 7      62
# 8      95
# 9     123
# 10    123
# 11    180
# 12    180
# 13    180
# 14    205
# 15    215
# 16    230
# 17     66
# 18     52
# 19     65
# 20     97
# 21    150
# 22    150
# 23    245
# 24    175
# 25     66
# 26     91
# 27    113
# 28    264
# 29    175
# 30    335
# 31    109
# Name: hp, dtype: int64

# %%
plt.plot(mtcars['hp'],mtcars['mpg']) # wrong representation

# %%
# plt.figure(figsize=(8,3))
plt.scatter(mtcars['hp'],mtcars['mpg'])

# %%
mtcars.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
mtcars.shape
# Out:
# (32, 11)

# %%
mtcars['cyl'].value_counts()
# Out:
# cyl
# 8    14
# 4    11
# 6     7
# Name: count, dtype: int64

# %%
mtcars['gear'].value_counts()
# Out:
# gear
# 3    15
# 4    12
# 5     5
# Name: count, dtype: int64

# %%
# mtcars['hp'].value_counts() # not good inference

# %%
# table 
pd.crosstab(mtcars.gear,mtcars.cyl)
# Out:
# cyl   4  6   8
# gear
# 3     1  2  12
# 4     8  4   0
# 5     2  1   2

# %%
# bar plot between 2 different categories 
pd.crosstab(mtcars.gear,mtcars.cyl).plot(kind="bar")
# Out:
# <Axes: xlabel='gear'>

# %%
# mtcars["gear"]
# mtcars.gear

# %%
mtcars.gear.value_counts()
# Out:
# gear
# 3    15
# 4    12
# 5     5
# Name: count, dtype: int64

# %%
# mtcars["gear"].value_counts()
mtcars.gear.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
plt.pie(mtcars['gear'].value_counts(),autopct='%0.2f %%',labels=['3','4','5']);

# %%
mtcars['cyl'].value_counts()
# Out:
# cyl
# 8    14
# 4    11
# 6     7
# Name: count, dtype: int64

# %%
# plt.pie(mtcars['mpg'].value_counts()) #,autopct='%0.2f %%',labels=['8','4','6']);
# plt.show()

# %%
plt.pie(mtcars['cyl'].value_counts(),autopct='%0.2f %%',labels=['8','4','6']);

# %%
mtcars.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
# plt.scatter(mtcars.gear,mtcars.hp)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(mtcars.mpg,mtcars.wt ) ## scatter plot of two variables
plt.xlabel('MPG')
plt.ylabel('Weight')
plt.title('Scatter Plot')
plt.suptitle('MPG WT relation', size=15, y=1.005)
# Out:
# Text(0.5, 1.005, 'MPG WT relation')

# %%
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
len(mtcars[mtcars['mpg']<20.09])
# Out:
# 18

# %%
# Graphical Representation of data

# Histogram
plt.hist(mtcars['mpg'])
plt.show()

# %%
plt.hist(mtcars['mpg'],facecolor ="red",edgecolor ="blue",bins =10);
#creates histogram with 5bins and colours filled init.

# %%
mtcars.describe()

# %%
# len(mtcars[(mtcars['mpg']>24) & (mtcars['mpg']<34)])

# %%
mtcars['mpg']
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
# 25% -(IQR*1.5) to claculate lower minimum value for an outlier
# 75% -(IQR*1.5) to claculate upper maximum value for an outlier

# %%
#Boxplot
#help(plt.boxplot)

plt.boxplot(mtcars['mpg'],vert = False);

# %%
plt.boxplot(mtcars['mpg'],vert =True);
plt.ylabel("MPG")
plt.xlabel("Boxplot")
plt.title("Boxplot");  # for vertical

# %%
#Violin Plot
#help(plt.violinplot)
plt.violinplot(mtcars["mpg"],vert=False);

# %% [markdown]
# # seaborn

# %%
# pip install seaborn

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips') # inbuilt data set

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
df['size'].sum()
# Out:
# 627

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Univariate → “one variable” data visualization

# %% [markdown]
# # Box Violene and hist plot

# %%
plt.hist(df['total_bill']);

# %%
plt.violinplot(df['total_bill'],vert=False);

# %%
plt.hist(df['tip']);

# %%
plt.violinplot(df['tip'],vert=False);

# %%
plt.boxplot(df['tip'],vert = False);

# %%
plt.boxplot(df['total_bill'],vert=False);

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(data = df,x='tip')
# Out:
# <Axes: xlabel='tip'>

# %%
df2 = df[df['sex']=='Female']

# %%
df2.describe()
# Out:
#        total_bill        tip       size
# count   87.000000  87.000000  87.000000
# mean    18.056897   2.833448   2.459770
# std      8.009209   1.159495   0.937644
# min      3.070000   1.000000   1.000000
# 25%     12.750000   2.000000   2.000000
# 50%     16.400000   2.750000   2.000000
# 75%     21.520000   3.500000   3.000000
# max     44.300000   6.500000   6.000000

# %%
sns.boxplot(df,x='tip',y= 'sex')
# Out:
# <Axes: xlabel='tip', ylabel='sex'>

# %%
sns.boxplot(x='day', y='tip', data=df,hue='sex')
plt.ylabel('tip ($)')
# Out:
# Text(0, 0.5, 'tip ($)')

# %%
sns.violinplot(x='day', y='tip', data=df,hue='sex')
plt.ylabel('tip ($)')

plt.show()

# %%
r = [1,2]

# %%
r
# Out:
# [1, 2]

# %%
a,b = r
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)

# %%
fig, a = plt.subplots(nrows=1, ncols=2)
sns.boxplot(x='day', y='tip', data=df,ax=a[1])
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
fig, ax = plt.subplots(2,1)
sns.boxplot(x='day', y='tip', data=df,ax=ax[1])
plt.ylabel('tip ($)')
sns.boxplot(x='day', y='tip', hue = 'sex',data=df,ax=ax[0])
plt.ylabel('tip ($)')
# Out:
# Text(0, 0.5, 'tip ($)')

# %%
sns.stripplot(y = 'tip', data = df)
# Out:
# <Axes: ylabel='tip'>

# %%
#strip plot
# sns.stripplot(df,x='tip')
sns.stripplot(y ='tip', data=df,jitter=True)
plt.ylabel('tip ($)')
plt.show()

# %%
sns.stripplot(y='tip',hue = 'sex', data=df,jitter=True)#,size = 8)
# Out:
# <Axes: ylabel='tip'>

# %%
sns.stripplot(df,y = 'tip',x = 'day',hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
# #Grouping with stripplot()
# sns.stripplot( hue = 'sex', x ='day', y='tip',data=df,jitter=True)
# plt.ylabel('tip ($)')
# plt.show()

# %%
df['time'].value_counts()

# %%
sns.stripplot(x='day', y='tip', data=df, size=7,jitter=True, hue = 'time')
plt.ylabel('tip ($)')
plt.show()

# %%
#Swarm plot

sns.swarmplot(x='day', y='tip', data=df,hue='day')
plt.ylabel('tip ($)')
plt.show()

# %%
sns.swarmplot(x='day', y='tip', data=df, hue='sex')
plt.ylabel('tip ($)')
plt.show()

# %%
sns.swarmplot(x='sex', y='tip', data=df, hue='day')
plt.ylabel('tip ($)')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# #Changing orientation
# sns.swarmplot(x='tip', y='day', data=df, hue='sex',orient='h')
# plt.xlabel('tip ($)')
# plt.show()

# %%
# df.head()

# %%
# The subplot() function takes three arguments that describes the layout of the figure.

# %%
# fig, ax = plt.subplots(nrows=3, ncols=2)

# More than one Axes with plt.subplots, then the second item in the tuple is a NumPy array containing all the Axes
fig, axs = plt.subplots(3, 4)

# %%
plt.subplot(2, 4, 1)
# plt.subplot(2, 4, 2)
# Out:
# <Axes: >

# %%
import numpy as np

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2,3, 6)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([1, 5, 7, 11])

plt.subplot(2, 3, 1)
plt.plot(x,y)

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2,3, 6)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([1, 5, 7, 11])

plt.subplot(2, 3, 1)
plt.plot(x,y)

#plot 3:
x = np.array([0, 1, 2, 3])
y = np.array([15, 19, 25, 34])

plt.subplot(2,3, 4)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 1)
plt.plot(x,y)

plt.show()

# %%
import seaborn as sns
df =sns.load_dataset('tips') 
df

# %%
df.shape
# Out:
# (244, 7)

# %%
df['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.boxplot(x='size', data=df) # wrong represntation of data
# Out:
# <Axes: xlabel='size'>

# %%
df['size'].value_counts().plot(kind='pie') # this is right
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,3,2)
sns.boxplot( y='tip', data=df)
plt.ylabel('tip ($)')

plt.subplot(2,3,3)
sns.violinplot(x='day', y='tip', data=df,hue = 'day')
plt.ylabel('tip ($)')

plt.subplot(2,3,6)
sns.boxplot(x='day', y='tip', data=df,hue = 'day')
plt.ylabel('tip ($)')

plt.subplot(2,3,1)
sns.violinplot(x='day', y='tip', data=df)
plt.ylabel('tip ($)')

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 4)
plt.plot(x,y)
# plt.subplot(2,3,4)
# plt.subplot(2,3,1)
plt.show()

# %%
##Combining plots

sns.violinplot(x='day', y='tip', data=df, inner=None,color='lightgray')
sns.stripplot(x='day', y='tip', data=df, size=4,jitter=True,color='blue')
plt.ylabel('tip ($)')
plt.show()

# %% [markdown]
# ## Bivariate → “two variables” data visualization

# %%
#Joint plot

sns.jointplot(x= 'total_bill', y= 'tip', data=df, hue='sex')
plt.show()

# %% [markdown]
# people who make bill between 10 to 30 dollar pay tip 1.2 to 5 dollar to waiter

# %%
# Density plot
sns.jointplot(x='total_bill', y= 'tip', data=df,kind='kde',hue='sex')
plt.show()

# %%
#Pair plot

sns.pairplot(df)
plt.show()

# %%
df.corr(numeric_only=True)

# %%
sns.pairplot(df, hue='sex')
plt.show()

# %% [markdown]
# # Titanic data visualization

# %%
# import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Loading dataset

# %%
data = pd.read_csv("train.csv")
data

# %% [markdown]
# #survival - Survival (0 = No; 1 = Yes)
# class - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# name - Name
# sex - Sex
# age - Age
# sibsp - Number of Siblings/Spouses Aboard
# parch - Number of Parents/Children Aboard
# ticket - Ticket Number
# fare - Passenger Fare
# cabin - Cabin
# embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)

# %%
data.describe()

# %%
data['Sex'].value_counts().plot(kind='pie')

# %%
# data['Sex'].unique()

# %%
data['Pclass'].value_counts()

# %%
plt.hist(data['Age']);

# %% [markdown]
# ### Data types

# %%
data.info()

# %%
data['Embarked'].value_counts()

# %%
data.isnull().sum()

# %% [markdown]
# ### Proportion of target (Survived)

# %%
data['Survived'].value_counts()

# %%
data['Sex'].value_counts()

# %%
pd.pivot_table(data,values='Survived',columns='Pclass',index = ['Sex'],aggfunc='count')
# pd.pivot_table(df, values='D', index=['A', 'B'],columns=['C'], aggfunc="sum")

# %%
# data.groupby('Pclass')[['Survived','Sex']].count()

# %%
# data['Sex']=='male'

# %%
data[data['Sex']=='male']

# %%
data[data['Survived']==1]

# %%
da = data[(data['Survived']==1) & (data['Sex']=='female')]
da

# %%
da['Embarked'].value_counts()

# %%
# da.groupby('Pclass')[['Sex']].count()

# %% [markdown]
# ### Visual Exploration

# %%
f, ax = plt.subplots(figsize=(4,4))
sns.boxplot(y="Age",  data=data);

# %%
# f, ax = plt.subplots(figsize=(4,4))
# sns.boxplot(x="Age",  data=data);

# %%
f, ax = plt.subplots(figsize=(4,4))
sns.boxplot(x ='Survived', y="Age",  data=data,hue = 'Sex');

# %%
plt.subplots(figsize=(5,5))
sns.boxplot(x="Sex", y="Age", hue="Survived", data=data);

# %%
# f, ax = plt.subplots(figsize=(4,4))
# # f;
# sns.barplot(x='Sex', y="Survived",  data=data);

# %%
f, ax = plt.subplots(2,2,figsize=(10,10))
# f;
sns.boxplot(x='Sex', y="Age",  data=data, ax = ax[0,0]);
sns.boxplot(x="Sex", y="Age", hue="Survived", data=data,ax = ax[0,1]);

# %%
data['Pclass'].value_counts()

# %%
sns.boxplot(x="Pclass", y="Age", data=data, hue = 'Sex');

# %%
sns.boxplot(x="Pclass", y="Age", data=data, hue = 'Survived');

# %%
data

# %%
data.isnull().sum()

# %%
# data['Survived']==1

# %%
data[data['Survived']==1]

# %%
data

# %%
[data['Survived']==1,'Age']

# %%
# data.loc[data['Survived']==1,:]
data.loc[data['Survived']==1,'Age'].isnull().sum()

# %%
data.loc[data['Survived']==1,"Age"].dropna()

# %%
survived = data.loc[data['Survived']==1,"Age"].dropna()
sns.distplot(survived)
plt.title("Survived");

# %%
not_survived = data.loc[data['Survived']==0,"Age"].dropna()
sns.distplot(not_survived)
plt.title("Not Survived");

# %%
data

# %%
data.isnull().sum()

# %%
data.dropna()

# %%
data # no changes

# %%
data.drop('Cabin',axis=1,inplace=True)

# %%
data

# %%
sns.pairplot(data.dropna());

# %%
data.corr(numeric_only=True)

# %%
data.head()

# %%
# Pclass vs Survive
sns.FacetGrid(data, col='Survived', row='Pclass')

# %%
# Pclass vs Survive
grid = sns.FacetGrid(data, col='Survived', row='Pclass')
grid.map(plt.hist, 'Age', alpha=1, bins=10)
grid.add_legend()

# %%
sns.catplot(
    data=data, x='Survived', y='Age',
    col='Pclass',kind='box',  col_wrap=3
);

# %%
sns.catplot(
    data=data, x='Survived', y='Age',
    col='Pclass',kind='violin',  col_wrap=3
);

# %%
data['Embarked'].value_counts()

# %%
data[(data['Embarked']=='C') & (data['Sex']=='male')]['Survived']

# %%
sns.distplot(a=data[(data['Embarked']=='C') & (data['Sex']=='male')]['Survived'],bins=3,kde=False)
plt.title("Cherbourg")
plt.xticks([0,1])
plt.show()

# %%
sns.distplot(a=data[data['Embarked']=='C']['Survived'],bins=3,kde=False)
plt.title("Cherbourg")
plt.xticks([0,1])
plt.show()
plt.title("QueensTown")
sns.distplot(a=data[data['Embarked']=='Q']['Survived'],bins = 3,kde=False)
plt.xticks([0,1])

plt.show()
plt.title("Southampton")
sns.distplot(a=data[data['Embarked']=='S']['Survived'],bins=3,kde=False)
plt.xticks([0,1])

plt.show()
#Most of the Passengers embarked from Southampton

# %%
data.groupby('Pclass')['Survived'].count() # no inference we are getting here

# %%
figbi, axesbi = plt.subplots(2, 4, figsize=(20,10))
data.groupby('Pclass')['Survived'].count().plot(kind='bar',ax=axesbi[0,1],xlim=[0,1])
data.groupby('SibSp')['Survived'].count().plot(kind='bar',ax=axesbi[0,3],xlim=[0,1])
data.groupby('Parch')['Survived'].count().plot(kind='bar',ax=axesbi[0,2],xlim=[0,1])
data.groupby('Sex')['Survived'].count().plot(kind='bar',ax=axesbi[0,0],xlim=[0,1])
# data.groupby('Embarked')['Survived'].count().plot(kind='barh',ax=axesbi[1,0],xlim=[0,1])
sns.stripplot(x="Survived", y="Fare", data=data,ax=axesbi[1,2])
sns.violinplot(x="Survived", y="Age", data=data,ax=axesbi[1,1])
sns.boxplot(x="Survived", y="Fare", data=data,ax=axesbi[1,3])
